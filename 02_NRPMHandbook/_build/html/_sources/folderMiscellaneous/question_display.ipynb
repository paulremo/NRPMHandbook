# %% [markdown]
# # Here is a page where you can dynamically see Questions

# %%
import pandas as pd

data_cols = ["Number","Recommendation","Audit Question","Weight","Level","Description","Grade"]
datas = pd.read_csv("data/manufactoring_on_board.csv", header=0, names=data_cols, na_filter=False)

print(datas.Level[1])
datas
# Out:
# 4
#     Number                                     Recommendation  \
# 0        7  Procedures related to corrective actions inclu...
# 1        8  Procedures related to preventive actions inclu...
# 2       17  The subassembly varnishing activity. that must...
# 3       18  Maintenance procedures related to corrective a...
# 4       19  Based on the defined preventive maintenance pl...
# 5       21  This verification is less complicated than a p...
# 6       22  This filter assures that the final test that f...
# 7       23  It is important to perform the minimum number ...
# 8       25  It is essential to specifically monitor and ma...
# 9       33  Delegation of the general inspection assures o...
# 10      37  The particular subassembly drying task within ...
# 11      41  Operators must be provided with a workstation ...
# 12      42  Take readings of temperature profiles for each...
# 13      43  The description of actions to be carried out d...
# 14      46  Recording on an Anomaly datasheet type documen...
# 15      60  The different subassemblies are made and integ...
# 16      61  List and implement protection means to avoid r...
# 17      77  A clear statement of persons authorised to app...
# 18      84  Measure the bath contamination by sampling (fr...
# 19      88  Set up self-checking to filter human errors th...
# 20      89  It must be impossible for reliability to be re...
# 21      90  Setting up periodic store inventories prevents...
# 22      91  Set up protections against ESD for subassembli...
# 23      92  A number of production means parameters are pr...
# 24      93  Set up suitable protections if necessary to av...
# 25      94  Set up a self-test of testers in order to dete...
# 26      95  This cross check filters nonconformities befor...
# 27      96  A so-called conformity check must be identifie...
# 28      97  Use of the statistical process control by maki...
# 29      98  The special feature of the varnishing activity...
# 30      99  Accidental use of out-of-date consumables can ...
# 31     100  This involves monitoring of test execution ind...
# 32     101  This maintenance by metrological monitoring of...
# 33     102  The activity must be done under the permanent ...
# 34     112  Have high and low safety systems tied to inspe...
# 35     115  Possess a plan for qualification of a method o...
# 36     120  Include an inspection step (even visual) to as...
# 37     121  Provide preventive maintenance (by the use of ...
# 38     125  Wait for the time necessary to reach thermal e...
# 39     126  All preventive and corrective maintenance oper...
# 40     127  Make sure that varnish preparation (dosing) is...
# 41     128  Make sure that the operators are well informed...
# 42     129  Make sure that the final inspection of the var...
# 43     136  Make sure that the person who will perform the...
# 44     138  Make sure that the right software is loaded an...
# 45     139  Make sure that maintenance is done on producti...
# 46     140  Make sure that the operator has received train...
# 47     141  All overstresses must be detectable and quanti...
# 48     144  It is important that the person responsible fo...
# 49     145  Increase operators awareness about the verific...
# 50     153  Use measurements for verification of purchased...
# 51     154  Perform an inspection action (barcode reading....
# 52     155  Check that the test coverage during and after ...
#
#                                        Audit Question  Weight  Level  \
# 0   What process is used to collect technical even...    15.4      4
# 1   Do procedures related to preventive actions in...    15.6      4
# 2   Are inspection parameters monitored during the...     9.9      2
# 3   Does corrective maintenance take place as soon...     6.9      2
# 4   Is preventive maintenance planned to correct d...     4.0      3
# 5   Is there a periodic verification of programmin...     4.1      1
# 6   Are the skills of final test operators systema...     4.1      2
# 7   Are production and manipulation of subassembli...     6.5      1
# 8   Are data loaded in programmable production mea...     2.8      3
# 9   Is the subassembly varnishing inspection done ...     4.4      4
# 10  Is the subassembly drying activity after varni...     5.6      3
# 11  Are the instructions (protocol and particular ...     7.4      3
# 12  Are there any records of temperature profiles ...     6.9      3
# 13  How is it assured that production means are ad...     7.2      3
# 14  How are technical events or anomaly reports re...     7.6      3
# 15  How are priorities managed as a function of en...     3.1      2
# 16  Have means of protecting subassemblies during ...     7.3      2
# 17  How are changes to manufacturing processes con...    13.9      3
# 18  Is contamination of solder baths measured by s...     5.8      3
# 19  Is a self checking system applied to filter hu...     5.3      1
# 20  Are there any indicators to verify that a good...     6.0      3
# 21  Are checks made to assure that stock inventori...     5.5      3
# 22  Have you set up specific protections against E...    26.0      3
# 23  Are there any periodic verifications used to m...     4.9      2
# 24  Are there any appropriate protections to avoid...     6.0      1
# 25  Are there any self-tests of test tools in orde...     5.1      1
# 26  Is there a cross-check to optimise the final i...     5.6      1
# 27  Is there a conformity check when putting into ...     6.0      3
# 28  is there an SPC (Statistical Process Control) ...     4.5      1
# 29  Is there a detailed description of the varnish...     5.8      3
# 30  Is there a label for identification and withdr...     6.4      3
# 31  Is there a real time processing of test monito...     4.7      1
# 32  is there a preventive maintenance by metrologi...     5.9      1
# 33  Is a method used for checking drifts and malfu...     6.1      2
# 34  Are high and low safety systems provided tied ...     5.7      2
# 35  Is there a qualification plan of the method of...     6.5      1
# 36  Is there an inspection step (even visual) to a...     6.5      1
# 37  Is there a preventive maintenance to detect an...     4.7      1
# 38  Is a rest time between each silk screen printi...     6.4      2
# 39  Have plans for maintenance of production means...     6.7      1
# 40  Is the preparation (dosing) of varnish control...     5.9      3
# 41  Is there a procedure for assuring that operato...     4.4      1
# 42  Is it assured that the inspection on the final...     5.2      2
# 43  Is it checked that the procedure for implement...     5.1      1
# 44  Is it checked that the right software is loade...     6.7      2
# 45  Is a check carried out to assure that means ar...     5.9      2
# 46  Is it checked that the operator has received t...     8.5      2
# 47  Are means secured (drying oven T�) through dir...     6.6      2
# 48  Are personnel made aware about a visual verifi...     5.9      1
# 49  Are operators made aware of the need to verify...     5.9      1
# 50   Is the conformity of purchased products checked?     8.6      3
# 51  Is an inspection action (barcode reading. read...     6.1      3
# 52  Is it checked that the test coverage for burn-...     5.2      3
#
#                                           Description  Grade
# 0   Procedures related to corrective actions inclu...   46.2
# 1   Procedures for preventive actions do exist. th...   46.8
# 2   The varnishing activity is monitored by superv...    9.9
# 3   Corrective actions are made directly where the...    6.9
# 4   Real maintenance procedures are implemented fo...    8.0
# 5   There is no periodic verification of the progr...    0.0
# 6   The equivalent of an audit is done to monitor ...    4.1
# 7      No manipulation of subassemblies is automated.    0.0
# 8   A check and maintenance of data programmed in ...    5.6
# 9   A person other than the varnishing operator ma...   13.2
# 10  Operators drying the subassembly are experienc...   11.2
# 11  Instructions related to the activity to be per...   14.8
# 12  Readings are used to precisely know levels app...   13.8
# 13  Each production means is accompanied by a desc...   14.4
# 14  Every production problem. regardless of its na...   15.2
# 15  According to production planning. some priorit...    3.1
# 16  Protection means are identified but are partia...    7.3
# 17  Process changes are recorded. persons authoris...   27.8
# 18  The content of contaminating pollutant in the ...   11.6
# 19               No self-checking is done on the task    0.0
# 20  There are indicators to assure that a good sol...   12.0
# 21  Periodic inventories are made. If the date of ...   11.0
# 22  There are validated procedures for protection ...   52.0
# 23  Tools and instruments used for inspection of p...    4.9
# 24  No specific protection is used when cleaning s...    0.0
# 25               No self-test is done on the testers.    0.0
# 26  There is no cross-check at the final inspectio...    0.0
# 27  A real check on conformity of items is made be...   12.0
# 28  There is no inspection of the production proce...    0.0
# 29  The different actions to be carried out and th...   11.6
# 30  Consumables are correctly identified by labell...   12.8
# 31           There are no test monitoring indicators.    0.0
# 32  No preventive maintenance measure by metrologi...    0.0
# 33  There are several malfunction indicators for t...    6.1
# 34  Inspection and monitoring means can stop the a...    5.7
# 35  There is no plan specific to the method of rem...    0.0
# 36  No particular visual inspection is done during...    0.0
# 37  There is no preventive maintenance plan in pro...    0.0
# 38  A number of measures are applied during the co...    6.4
# 39  There is no revision and record of the plan fo...    0.0
# 40  The preparation of the varnish is controlled b...   11.8
# 41  No plan has been set up to inform operators an...    0.0
# 42  The final inspection of varnishing activities ...    5.2
# 43  There is no procedure or the operator cannot a...    0.0
# 44  After software has been loaded in a hardware s...    6.7
# 45  Maintenance is provided for production means a...    5.9
# 46  There is a verification to assure that the ope...    8.5
# 47  There are monitoring systems or other indicato...    6.6
# 48  No particular verification is done after compo...    0.0
# 49  No particular verification is made to check th...    0.0
# 50  Conformity of purchased products is verified b...   17.2
# 51  The identification of the product to be tested...   12.2
# 52  The test coverage rate during burn-in is verif...   10.4

# %%
from IPython.display import Markdown as md

def create_new_md(question):
    #print(question)
    q_id = datas.loc[datas['Audit Question'] == question].index[0]
    print(q_id)
    number_md = "## Question N° " + str(datas["Number"][q_id]) + "\n\n\n"
    audit_q_md = "### Audit Question : " + str(datas["Audit Question"][q_id]) + "\n\n"
    desc_md = "### Description : " + str(datas["Description"][q_id]) + "\n\n"
    rec_md = "### Recommendation : " + str(datas["Recommendation"][q_id]) + "\n\n"
    weight_md = "### Weight : " + str(datas["Weight"][q_id]) + "\n\n"
    level_md = "### Level : " + str(datas["Level"][q_id]) + "\n\n"
    grade_md = "### Grade : " + str(datas["Grade"][q_id]) + "\n\n"
    
    
    return(number_md + audit_q_md + desc_md + rec_md + weight_md + level_md + grade_md)

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import GridspecLayout
import ipywidgets as widgets

current_question_id = 0
q_txt = ""

all_questions = datas["Audit Question"]
#print(all_questions)


def response(change):
    #print(change.new)
    q_txt = create_new_md(change.new)
    print(q_txt)

question_selection = widgets.Dropdown(
    options=all_questions,
    value=all_questions[0],
    description='Question selection',
    disabled=False,
)
question_selection.observe(response, names="value")
question_selection
# Out:
# Dropdown(description='Question selection', options=('What process is used to collect technical events. to prod…
# 6
# ## Question N° 22
#
#
# ### Audit Question : Are the skills of final test operators systematically audited?
#
# ### Description : The equivalent of an audit is done to monitor the skills of operators performing the final product test. but it is not formally defined.
#
# ### Recommendation : This filter assures that the final test that forms the final verification milestone is carried out by a
# competent person and particularly a person whose skills are monitored to assure that the most
# recent requirements are taken into consideration.
# The audit assures that the operator reviews control over procedures and critical points. to achieve
# perfect confidence in execution of the final test.
#
# ### Weight : 4.1
#
# ### Level : 2
#
# ### Grade : 4.1
#
#
# 13
# ## Question N° 43
#
#
# ### Audit Question : How is it assured that production means are adapted to elements to be produced?
#
# ### Description : Each production means is accompanied by a description of a set of parameters to be
# verified before use on a subassembly. These are formally identified in a document that has not been validated by an authority independent from the operating entity.
#
# ### Recommendation : The description of actions to be carried out during application of a production tool on a subassembly must be sufficiently explicit to not allow interpretation by the operator that would result in accidental use of inappropriate means.
# It must be assured that the reliability of subassemblies will not be reduced by the use of an unsuitable tool.
#
# ### Weight : 7.2
#
# ### Level : 3
#
# ### Grade : 14.4
#
#
# 3
# ## Question N° 18
#
#
# ### Audit Question : Does corrective maintenance take place as soon as an anomaly appears on production means or produced subassemblies?
#
# ### Description : Corrective actions are made directly where the anomaly was observed. although a corrective maintenance plan was not set up.
#
# ### Recommendation : Maintenance procedures related to corrective actions in production must include:
# - Effective processing of complaints and subassembly nonconformity reports.
# - The search for causes of nonconformity related to the process and recording of the results of
# this search.
# - Determination of corrective actions necessary to eliminate causes of nonconformity.
# - Application of control means to assure that the corrective action is implemented and that it
# produces the required effect.
#
# ### Weight : 6.9
#
# ### Level : 2
#
# ### Grade : 6.9

# %%
print(q_txt)
md(q_txt)

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <body>
# <h3>onClick event on JavaScript Button to display text</h3>
# <p>JavaScript element triggers an onClick function</p>
# <button onclick="clickText()">Click to show text</button>
# <p id="btn"></p>
# <script>
# function clickText() {
# document.getElementById("btn").innerHTML = "You have clicked on JavaScript button";
# }
# </script>
# </body>
# </html>
