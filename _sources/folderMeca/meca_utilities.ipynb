# %% [markdown]
# # Utilities for Meca part

# %%
import pandas as pd
from myst_nb import glue

df1 = pd.read_html("table4_1.html")
datas1 = pd.DataFrame(df1[0])

glue("meca_table4_1",datas1)
# Out:
#    Root cause category  \
# 0      Random failures
# 1    Wear-out failures
# 2   Extrinsic failures
# 3  Systematic failures
#
#   Coverage by the mechanical reliability prediction  methodology
# 0  Considered by the methods described in Section...
# 1  Considered by the methods described in Section...
# 2  Foreseen extrinsic effects due to the launch e...
# 3  Process related failures due to minor design a...

# %%
df2 = pd.read_html("table4_8.html")
datas2 = pd.DataFrame(df2[0])

glue("meca_table4_8",datas2)
# Out:
#                                     Material or item  \
# 0                                 Metallic materials
# 1                                    Metallic shells
# 2                              Compound fibre carbon
# 3                                 Screw, rivet, weld
# 4                                            Bonding
# 5                                          Honeycomb
# 6                                 Structural inserts
# 7                                  Equipment inserts
# 8  *Remark: the skin CoV corresponds to the Coeff...
#
#                             Strength characteristics  \
# 0  Fracture strength (ultimate stress)  Yield str...
# 1         Buckling strength (under combined loading)
# 2                 Fracture strength (no yield limit)
# 3                                  Fracture strength
# 4                                     Shear strength
# 5  Strength w.r.t. tension loading  Strength w.r....
# 6  Strength w.r.t. axial loading  Strength w.r.t....
# ...

# %%
df3 = pd.read_html("table4_9.html")
datas3 = pd.DataFrame(df3[0])

glue("meca_table4_9",datas3)
# Out:
#                                      Type of loading        CoV
# 0                              Launch vehicle thrust         5%
# 1                  Launch vehicle other static loads        30%
# 2                                    Transient loads        50%
# 3  Thermo-elastic loads: correlated temperatures ...  7.5%  20%
# 4                                  Deployment shocks        10%
# 5                                     Thruster loads         2%
# 6                           Acoustic vibration loads        40%
# 7                               Sine vibration loads        20%
